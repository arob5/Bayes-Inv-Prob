# %%
import os
import copy
os.getcwd()
# Out:
# '/Users/vigneshsomjit/Git/Bayes-Inv-Prob/bip/notebooks'

# %%
import sys
sys.path.append("..") # Go to parent directory 
from param import *
from dist import *

# %%
# Define a 2-dimensional Normal distribution:
m = [0.0, 0.0]         # Mean vector: a 2D vector.
C = [[1.0, 0.0],       # Covariance matrix: a 2x2 identity matrix.
     [0.0, 1.0]]

# Instantiate the Normal distribution.
normal_dist = norm(m, C)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       3 C = [[1.0, 0.0],       # Covariance matrix: a 2x2 identity matrix.
#       4      [0.0, 1.0]]
#       6 # Instantiate the Normal distribution.
# ----> 7 normal_dist = norm(m, C)
#
# File ~/Git/Bayes-Inv-Prob/bip/notebooks/../dist.py:59, in norm.__init__(self, m, C)
#      56 init_values = {"m": m, "C": C}
#      58 # Initialize the Distribution's attributes.
# ---> 59 super().__init__(param_group, init_values)
#      61 # Create the underlying SciPy multivariate normal distribution instance.
#      62 self._rv = sp.multivariate_normal(
#      63     mean=self.dist_param.values["m"], # Use the value property defined in ParamGroupValues
#      64     cov=self.dist_param.values["C"]
#      65 )
#
# File ~/Git/Bayes-Inv-Prob/bip/notebooks/../dist.py:20, in dist.__init__(self, param_group, init_values)
# ...

# %%
# -------------------------------------------------------------------------
# Test 1: Display the parameter metadata (rv_info) from your param package.
print("===== Distribution Metadata (rv_info) =====")
print(normal_dist.rv_info)
# This output uses the __str__ method defined in your ParamGroup class,
# so you can see all parameter names, their types, shapes, and constraints.

# -------------------------------------------------------------------------
# Test 2: Display the actual parameter values stored in dist_param.
print("\n===== Parameter Values (dist_param) =====")
for param_name, value in normal_dist.dist_param.values.items():
    print(f"{param_name} =\n{value}\n")
# This demonstrates that the values you provided for 'm' and 'C'
# have been validated against the metadata.

# -------------------------------------------------------------------------
# Test 3: Use the sample() method to generate 5 samples.
samples = normal_dist.sample(5)
print("===== 5 Samples drawn from the Normal distribution =====")
print(samples)

# -------------------------------------------------------------------------
# Test 4: Compute the density at a specific test point.
test_point = np.array([0.0, 0.0])
density_val = normal_dist.density(test_point)
print("\n===== Density at test point [0.0, 0.0] =====")
print(density_val)
